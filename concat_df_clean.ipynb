# %%
import pandas as pd

# %%
df = pd.read_pickle(r'C:\Users\041674\VSCode\デジタル化効果集計\combined_df.pickle')
df.head()
# Out:
#        導入部門 導入担当者        導入日  効果（分/年）                       ファイル名    事業区分
# 0  CRG製造第二課  三上光平 2024-01-25    240.0  【T23-029】 水平展開効果算出シート.xlsx  CRG製造部

# %%
df.describe()
# Out:
#                        導入日
# count                   42
# mean   2023-06-26 12:00:00
# min    2023-02-06 00:00:00
# 25%    2023-04-17 00:00:00
# 50%    2023-05-20 00:00:00
# 75%    2023-09-27 18:00:00
# max    2024-01-25 00:00:00

# %%
# '事業区分'カラムを追加し、'導入部門'列の値に基づいて'A事業'または'B事業'と判定する関数を定義する
def determine_business(x):
    if x in ['内部統制推進室', ]:
        return '内部統制推進室'
    elif x in ['CIMS推進室',]:
        return 'CIMS推進室'
    elif x in ['管理課','人事課','施設保全課','環境管理課','安全衛生課']:
        return '人事施設部'
    elif x in ['経理課', 'IT推進課', '総合企画課']:
        return '経営管理部'
    elif x in ['品質保証第一課','品質保証第二課','品質保証第三課', '製品評価課']:
        return '品質保証部'
    elif x in ['調達第一課','調達第二課','部品QA課']:
        return '調達部'
    elif x in ['第一技術開発室','第一技術開発室', '生産技術課', '工機課']:
        return '技術開発部'
    elif x in ['生産企画部', '生産管理第一課','生産管理第二課', '製品管理課']:
        return '生産管理第一部'
    elif x in ['生産管理第三課','生産管理第四課']:
        return '生産管理第二部'
    elif x in ['CRG技術第一課','CRG技術第二課','CRG技術第三課']:
        return 'CRG技術部'
    elif x in ['CRG製造第一課', 'CRG製造第二課', 'CRG製造第三課', 'CRG製造第四課']:
        return 'CRG製造部'
    elif x in ['部品製造第一課', '部品製造第二課', '部品製造第三課', '部品製造第四課']:
        return '部品製造部'
    elif x in ['ICB製造第一課', 'ICB製造第二課']:
        return 'ICB製造部'
    elif x in ['ICB技術課','ICB組立推進課']:
        return 'ICB技術課'
    elif x in ['SEN技術第一課','SEN技術第二課','SEN技術第三課']:
        return 'SEN技術部'
    elif x in ['SEN製造第一課','SEN製造第二課','SEN製造第三課']:
        return 'SEN製造部'
    elif x in ['医療システム技術QA課', '医療システム製造課']:
        return '医療システム製造部'
    else:
        return '不明'

# %%
# apply関数を使って、'導入部門'列の各値に対して判定関数を適用する
df['事業区分'] = df['導入部門'].apply(determine_business)
df
# Out:
#            導入部門  導入担当者        導入日 効果（分/年）                       ファイル名    事業区分
# 0           工機課  千葉 紳吾 2023-04-07  4236.0  【T22-001】 水平展開効果算出シート.xlsx   技術開発部
# 1    コンポーネント管理課  太田　拓美 2023-12-11   720.0  【T22-002】 水平展開効果算出シート.xlsx      不明
# 2       M2プロ推進課  中田　浩司 2023-03-10   900.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 3       M2製造技術課  三浦　陽介 2023-03-10  1300.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 4        コンポ技術課   秋田　訓 2023-03-10   900.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 5        コンポ製造課  須藤　将人 2023-03-10   300.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 6        コンポ管理課   清野　真 2023-02-06   770.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 7        HOT2プロ  對馬　昭彦 2023-03-10  1400.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 8         生産技術課   中嶋淳二 2023-04-19   120.0  【T22-018】 水平展開効果算出シート.xlsx   技術開発部
# 9         生産技術課   中嶋淳二 2023-04-19   960.0  【T22-019】 水平展開効果算出シート.xlsx   技術開発部
# 10      部品製造第一課  三上　貴大 2023-03-29  840分/年    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 11      部品製造第二課  高谷　美穂 2023-03-30  173分/年    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 12  M2プロジェクト推進課  中田　浩司 2023-04-17     160    T22-045 水平展開効果算出シート.xlsx      不明
# 13      M2製造技術課  三浦　陽介 2023-04-17    1240    T22-045 水平展開効果算出シート.xlsx      不明
# 14   コンポーネント技術課   秋田　訓 2023-04-17     160    T22-045 水平展開効果算出シート.xlsx      不明
# 15   コンポーネント製造課  須藤　将人 2023-04-17    1480    T22-045 水平展開効果算出シート.xlsx      不明
# 16   コンポーネント管理課   清野　真 2023-04-17     180    T22-045 水平展開効果算出シート.xlsx      不明
# 17   HOT2プロジェクト  對馬　昭彦 2023-04-17     700    T22-045 水平展開効果算出シート.xlsx      不明
# 18     CRG物流管理課  越田　希帆 2023-05-08     402    T22-045 水平展開効果算出シート.xlsx      不明
# 19      部品製造第三課   葛原深雪 2023-06-20     300    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 20      部品製造第四課   澤田陽子 2023-06-20     120    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 21     CRG技術第二課    藤田瞬 2023-04-18   400.0  【T23-029】 水平展開効果算出シート.xlsx  CRG技術部
# 22          人事課  古川裕生志 2023-04-20   400.0  【T23-029】 水平展開効果算出シート.xlsx   人事施設部
# 23     CRG技術第二課   成田和穂 2023-09-14   240.0  【T23-029】 水平展開効果算出シート.xlsx  CRG技術部
# 24      CRG製造三課   長内光平 2023-09-14   240.0  【T23-029】 水平展開効果算出シート.xlsx      不明
# 25      SEN製造一課   清水博信 2023-09-15   240.0  【T23-029】 水平展開効果算出シート.xlsx      不明
# 26     CRG技術第3課  五十嵐彩子 2023-11-07   240.0  【T23-029】 水平展開効果算出シート.xlsx      不明
# 27     CRG製造第二課   三上光平 2024-01-25   240.0  【T23-029】 水平展開効果算出シート.xlsx  CRG製造部
# 28   コンポーネント管理課   太田拓美 2023-10-04   360.0  【T23-035】 水平展開効果算出シート.xlsx      不明
# 29   ＨＯＴ２プロジェクト   葛西　裕 2023-05-15  1200.0  【T23-036】 水平展開効果算出シート.xlsx      不明
# 30        生産技術課   浅利　翼 2023-05-26  1200.0  【T23-036】 水平展開効果算出シート.xlsx   技術開発部
# 31        生産技術課     浅利 2023-05-25     0.0  【T23-037】 水平展開効果算出シート.xlsx   技術開発部
# 32        技術開発室   小泉新也 2023-06-08    83.0  【T23-042】 水平展開効果算出シート.xlsx      不明
# 33     CRG技術第3課  五十嵐彩子 2023-11-07   200.0  【T23-045】 水平展開効果算出シート.xlsx      不明
# 34      SEN製造一課   清水博信 2023-09-15     8.0  【T23-052】 水平展開効果算出シート.xlsx      不明
# 35        生産技術課     浅利 2023-09-12    12.0  【T23-053】 水平展開効果算出シート.xlsx   技術開発部
# 36     CRG技術第3課  五十嵐彩子 2023-11-07     0.0  【T23-053】 水平展開効果算出シート.xlsx      不明
# 37      部品製造第三課   下山泰史 2023-10-25   192.0  【T23-055】 水平展開効果算出シート.xlsx   部品製造部
# 38     CRG製造第一課  赤石　和也 2023-10-02  900分/年  【T23-059】 水平展開効果算出シート.xlsx  CRG製造部
# 39   コンポーネント管理課  太田　拓美 2023-10-04   720.0  【T23-061】 水平展開効果算出シート.xlsx      不明
# 40        生産技術課   中嶋淳二 2023-10-10   960.0  【T23-061】 水平展開効果算出シート.xlsx   技術開発部
# 41        生産技術課     浅利 2023-10-30   600.0  【T23-069】 水平展開効果算出シート.xlsx   技術開発部

# %%
df[df['事業区分'] == '不明']
# Out:
#            導入部門  導入担当者        導入日 効果（分/年）                       ファイル名 事業区分
# 1    コンポーネント管理課  太田　拓美 2023-12-11   720.0  【T22-002】 水平展開効果算出シート.xlsx   不明
# 2       M2プロ推進課  中田　浩司 2023-03-10   900.0  【T22-015】 水平展開効果算出シート.xlsx   不明
# 3       M2製造技術課  三浦　陽介 2023-03-10  1300.0  【T22-015】 水平展開効果算出シート.xlsx   不明
# 4        コンポ技術課   秋田　訓 2023-03-10   900.0  【T22-015】 水平展開効果算出シート.xlsx   不明
# 5        コンポ製造課  須藤　将人 2023-03-10   300.0  【T22-015】 水平展開効果算出シート.xlsx   不明
# 6        コンポ管理課   清野　真 2023-02-06   770.0  【T22-015】 水平展開効果算出シート.xlsx   不明
# 7        HOT2プロ  對馬　昭彦 2023-03-10  1400.0  【T22-015】 水平展開効果算出シート.xlsx   不明
# 12  M2プロジェクト推進課  中田　浩司 2023-04-17     160    T22-045 水平展開効果算出シート.xlsx   不明
# 13      M2製造技術課  三浦　陽介 2023-04-17    1240    T22-045 水平展開効果算出シート.xlsx   不明
# 14   コンポーネント技術課   秋田　訓 2023-04-17     160    T22-045 水平展開効果算出シート.xlsx   不明
# 15   コンポーネント製造課  須藤　将人 2023-04-17    1480    T22-045 水平展開効果算出シート.xlsx   不明
# 16   コンポーネント管理課   清野　真 2023-04-17     180    T22-045 水平展開効果算出シート.xlsx   不明
# 17   HOT2プロジェクト  對馬　昭彦 2023-04-17     700    T22-045 水平展開効果算出シート.xlsx   不明
# 18     CRG物流管理課  越田　希帆 2023-05-08     402    T22-045 水平展開効果算出シート.xlsx   不明
# 24      CRG製造三課   長内光平 2023-09-14   240.0  【T23-029】 水平展開効果算出シート.xlsx   不明
# 25      SEN製造一課   清水博信 2023-09-15   240.0  【T23-029】 水平展開効果算出シート.xlsx   不明
# 26     CRG技術第3課  五十嵐彩子 2023-11-07   240.0  【T23-029】 水平展開効果算出シート.xlsx   不明
# 28   コンポーネント管理課   太田拓美 2023-10-04   360.0  【T23-035】 水平展開効果算出シート.xlsx   不明
# 29   ＨＯＴ２プロジェクト   葛西　裕 2023-05-15  1200.0  【T23-036】 水平展開効果算出シート.xlsx   不明
# 32        技術開発室   小泉新也 2023-06-08    83.0  【T23-042】 水平展開効果算出シート.xlsx   不明
# 33     CRG技術第3課  五十嵐彩子 2023-11-07   200.0  【T23-045】 水平展開効果算出シート.xlsx   不明
# 34      SEN製造一課   清水博信 2023-09-15     8.0  【T23-052】 水平展開効果算出シート.xlsx   不明
# 36     CRG技術第3課  五十嵐彩子 2023-11-07     0.0  【T23-053】 水平展開効果算出シート.xlsx   不明
# 39   コンポーネント管理課  太田　拓美 2023-10-04   720.0  【T23-061】 水平展開効果算出シート.xlsx   不明

# %%
df.sort_values('導入日', ascending=False)
# Out:
#            導入部門  導入担当者        導入日 効果（分/年）                       ファイル名    事業区分
# 27     CRG製造第二課   三上光平 2024-01-25   240.0  【T23-029】 水平展開効果算出シート.xlsx  CRG製造部
# 1    コンポーネント管理課  太田　拓美 2023-12-11   720.0  【T22-002】 水平展開効果算出シート.xlsx      不明
# 33     CRG技術第3課  五十嵐彩子 2023-11-07   200.0  【T23-045】 水平展開効果算出シート.xlsx      不明
# 36     CRG技術第3課  五十嵐彩子 2023-11-07     0.0  【T23-053】 水平展開効果算出シート.xlsx      不明
# 26     CRG技術第3課  五十嵐彩子 2023-11-07   240.0  【T23-029】 水平展開効果算出シート.xlsx      不明
# 41        生産技術課     浅利 2023-10-30   600.0  【T23-069】 水平展開効果算出シート.xlsx   技術開発部
# 37      部品製造第三課   下山泰史 2023-10-25   192.0  【T23-055】 水平展開効果算出シート.xlsx   部品製造部
# 40        生産技術課   中嶋淳二 2023-10-10   960.0  【T23-061】 水平展開効果算出シート.xlsx   技術開発部
# 39   コンポーネント管理課  太田　拓美 2023-10-04   720.0  【T23-061】 水平展開効果算出シート.xlsx      不明
# 28   コンポーネント管理課   太田拓美 2023-10-04   360.0  【T23-035】 水平展開効果算出シート.xlsx      不明
# 38     CRG製造第一課  赤石　和也 2023-10-02  900分/年  【T23-059】 水平展開効果算出シート.xlsx  CRG製造部
# 25      SEN製造一課   清水博信 2023-09-15   240.0  【T23-029】 水平展開効果算出シート.xlsx      不明
# 34      SEN製造一課   清水博信 2023-09-15     8.0  【T23-052】 水平展開効果算出シート.xlsx      不明
# 23     CRG技術第二課   成田和穂 2023-09-14   240.0  【T23-029】 水平展開効果算出シート.xlsx  CRG技術部
# 24      CRG製造三課   長内光平 2023-09-14   240.0  【T23-029】 水平展開効果算出シート.xlsx      不明
# 35        生産技術課     浅利 2023-09-12    12.0  【T23-053】 水平展開効果算出シート.xlsx   技術開発部
# 19      部品製造第三課   葛原深雪 2023-06-20     300    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 20      部品製造第四課   澤田陽子 2023-06-20     120    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 32        技術開発室   小泉新也 2023-06-08    83.0  【T23-042】 水平展開効果算出シート.xlsx      不明
# 30        生産技術課   浅利　翼 2023-05-26  1200.0  【T23-036】 水平展開効果算出シート.xlsx   技術開発部
# 31        生産技術課     浅利 2023-05-25     0.0  【T23-037】 水平展開効果算出シート.xlsx   技術開発部
# 29   ＨＯＴ２プロジェクト   葛西　裕 2023-05-15  1200.0  【T23-036】 水平展開効果算出シート.xlsx      不明
# 18     CRG物流管理課  越田　希帆 2023-05-08     402    T22-045 水平展開効果算出シート.xlsx      不明
# 22          人事課  古川裕生志 2023-04-20   400.0  【T23-029】 水平展開効果算出シート.xlsx   人事施設部
# 9         生産技術課   中嶋淳二 2023-04-19   960.0  【T22-019】 水平展開効果算出シート.xlsx   技術開発部
# 8         生産技術課   中嶋淳二 2023-04-19   120.0  【T22-018】 水平展開効果算出シート.xlsx   技術開発部
# 21     CRG技術第二課    藤田瞬 2023-04-18   400.0  【T23-029】 水平展開効果算出シート.xlsx  CRG技術部
# 17   HOT2プロジェクト  對馬　昭彦 2023-04-17     700    T22-045 水平展開効果算出シート.xlsx      不明
# 16   コンポーネント管理課   清野　真 2023-04-17     180    T22-045 水平展開効果算出シート.xlsx      不明
# 15   コンポーネント製造課  須藤　将人 2023-04-17    1480    T22-045 水平展開効果算出シート.xlsx      不明
# 14   コンポーネント技術課   秋田　訓 2023-04-17     160    T22-045 水平展開効果算出シート.xlsx      不明
# 13      M2製造技術課  三浦　陽介 2023-04-17    1240    T22-045 水平展開効果算出シート.xlsx      不明
# 12  M2プロジェクト推進課  中田　浩司 2023-04-17     160    T22-045 水平展開効果算出シート.xlsx      不明
# 0           工機課  千葉 紳吾 2023-04-07  4236.0  【T22-001】 水平展開効果算出シート.xlsx   技術開発部
# 11      部品製造第二課  高谷　美穂 2023-03-30  173分/年    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 10      部品製造第一課  三上　貴大 2023-03-29  840分/年    T22-045 水平展開効果算出シート.xlsx   部品製造部
# 7        HOT2プロ  對馬　昭彦 2023-03-10  1400.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 5        コンポ製造課  須藤　将人 2023-03-10   300.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 4        コンポ技術課   秋田　訓 2023-03-10   900.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 3       M2製造技術課  三浦　陽介 2023-03-10  1300.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 2       M2プロ推進課  中田　浩司 2023-03-10   900.0  【T22-015】 水平展開効果算出シート.xlsx      不明
# 6        コンポ管理課   清野　真 2023-02-06   770.0  【T22-015】 水平展開効果算出シート.xlsx      不明
